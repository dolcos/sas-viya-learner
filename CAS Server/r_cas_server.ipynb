# %%
library(swat)

cashost <- "sas-cas-server-default-client"
casport <- 5570                               # binary port inside Viya pods
access_token <- Sys.getenv("ACCESS_TOKEN")    # Azure Marketplace sets this for you

conn <- CAS(cashost, casport, password = access_token)

# Take a look at the connection/session
conn
cas.builtins.serverStatus(conn)               # server status / nodes, etc.
class(conn)

abt <- cas.builtins.about(conn)
abt$About[["Viya Version"]]

cas.table.fileInfo(conn, caslib = "casuser")
# Out:
# SWAT 1.9.0
#
# NOTE: Connecting to CAS and generating CAS action functions for loaded
#       action sets...
#
# NOTE: To generate the functions with signatures (for tab completion), set
#       options(cas.gen.function.sig=TRUE).
# CAS(hostname=sas-cas-server-default-client, port=5570, username=alfonso.then@barna.edu.do, session=cce20eed-a7e5-8d44-a8b4-8a23edf0c76a, protocol=cas)
# NOTE: Grid node action status report: 1 nodes, 30 total actions executed.
# $About
# $About$CAS
# [1] "Cloud Analytic Services"
#
# $About$Version
# [1] "4.00"
#
# $About$VersionLong
# [1] "V.04.00M0P03062025"
#
# $About$`Viya Release`
# [1] "20251010.1760100479962"
#
# $About$`Viya Version`
# [1] "Long-Term Support 2025.03"
#
# $About$Copyright
# [1] "Copyright © 2014-2025 SAS Institute Inc. All Rights Reserved."
#
# $About$ServerTime
# [1] "2025-11-05T19:22:48Z"
#
# $About$System
# $About$System$Hostname
# [1] "controller.sas-cas-server-default.viya.svc.cluster.local"
#
# $About$System$`OS Name`
# [1] "Linux"
#
# $About$System$`OS Family`
# [1] "LIN X64"
#
# $About$System$`OS Release`
# [1] "5.15.0-1089-azure"
#
# $About$System$`OS Version`
# [1] "#98-Ubuntu SMP Wed Apr 30 21:20:48 UTC 2025"
#
# $About$System$`Model Number`
# [1] "x86_64"
#
# $About$System$`Linux Distribution`
# [1] "Red Hat Enterprise Linux release 8.10 (Ootpa)"
#
#
# $About$license
# $About$license$site
# [1] "ENGAGE PLATFORM VIYA ADVANCED"
#
# $About$license$siteNum
# [1] 70180938
#
# $About$license$expires
# [1] "31Dec2027:00:00:00"
#
# $About$license$gracePeriod
# [1] 0
#
# $About$license$warningPeriod
# [1] 15
#
#
# $About$CASHostAccountRequired
# [1] "OPTIONAL"
#
# $About$Transferred
# [1] "NO"
#
# $About$CASCacheLocation
# [1] "CAS Disk Cache"
#
#
# $server
#   nodes actions
# 1     1      30
#
# $nodestatus
#                                                       name       role uptime
# 1 controller.sas-cas-server-default.viya.svc.cluster.local controller  0.612
#   running stalled
# 1       0       0
# [1] "CAS"
# attr(,"package")
# [1] "swat"
# NOTE: Grid node action status report: 1 nodes, 31 total actions executed.
# [1] "Long-Term Support 2025.03"
# $FileInfo
#   Permission    Owner    Group                             Name     Size
# 1 -rw-r--r-- 42344528 42344528           hotels_vienna.sas7bdat   196608
# 2 -rw-r--r-- 42344528 42344528           hotels_europe.sas7bdat 33882112
# 3 -rwxr-xr-x 42344528 42344528 NODEOUTPUT_1761915760873.sashdat    32368
# 4 -rw-r--r-- 42344528 42344528        haiti_earthquake.sas7bdat  2097152
#   Encryption                      Time    ModTime
# 1            2025-10-30T15:58:32+00:00 2077459112
# 2            2025-10-31T18:57:22+00:00 2077556242
# 3       NONE 2025-10-31T13:02:59+00:00 2077534979
# 4            2025-10-31T21:04:17+00:00 2077563857

# %%
cars_df <- read.csv("data/courses/CASL/data/my_data/cars.csv")

# Upload to CAS as an in-memory table
invisible(
    as.casTable(conn, cars_df,
            casOut = list(name = "cars",
                          caslib = "casuser",
                          replace = TRUE))
)

# Verify the in-memory table exists
cas.table.tableInfo(conn, caslib = "casuser")
# Out:
# [1] "NOTE: Cloud Analytic Services made the uploaded file available as table CARS in caslib CASUSER(alfonso.then@barna.edu.do)."
# $TableInfo
#                       Name   Rows Columns IndexedColumns Encoding
# 1                     CARS    428      12              0    utf-8
# 2            HOTELS_VIENNA    428      25              0    utf-8
# 3 NODEOUTPUT_1761915760873    250      12              0    utf-8
# 4            HOTELS_EUROPE 145306      25              0    utf-8
#         CreateTimeFormatted          ModTimeFormatted       AccessTimeFormatted
# 1 2025-11-05T20:06:51+00:00 2025-11-05T20:06:51+00:00 2025-11-05T20:06:51+00:00
# 2 2025-10-30T16:06:50+00:00 2025-10-30T16:06:50+00:00 2025-11-02T12:44:08+00:00
# 3 2025-10-31T13:03:03+00:00 2025-10-31T13:03:03+00:00 2025-10-31T19:01:28+00:00
# 4 2025-10-31T19:02:16+00:00 2025-10-31T19:02:16+00:00 2025-11-02T12:37:40+00:00
#   JavaCharSet CreateTime    ModTime AccessTime Global Repeated View MultiPart
# 1        UTF8 2077992411 2077992411 2077992411      0        0    0         0
# 2        UTF8 2077459610 2077459610 2077706648      1        0    0         0
# 3        UTF8 2077534983 2077534983 2077556488      1        0    0         0
# 4        UTF8 2077556536 2077556536 2077706260      1        0    0         0
#                         SourceName                       SourceCaslib
# 1
# 2           hotels_vienna.sas7bdat CASUSER(alfonso.then@barna.edu.do)
# 3 NODEOUTPUT_1761915760873.sashdat CASUSER(alfonso.then@barna.edu.do)
# 4           hotels_europe.sas7bdat CASUSER(alfonso.then@barna.edu.do)
#   Compressed                   Creator Modifier    SourceModTimeFormatted
# 1          0 alfonso.then@barna.edu.do          2025-11-05T20:06:51+00:00
# 2          0 alfonso.then@barna.edu.do          2025-10-30T15:58:32+00:00
# 3          0 alfonso.then@barna.edu.do          2025-10-31T13:02:59+00:00
# 4          0 alfonso.then@barna.edu.do          2025-10-31T18:57:22+00:00
#   SourceModTime TableRedistUpPolicy
# 1    2077992411       Not Specified
# 2    2077459112       Not Specified
# 3    2077534979       Not Specified
# 4    2077556242       Not Specified

# %%
castbl <- defCasTable(conn, 'cars')

print(class(castbl))

df <- head(to.casDataFrame(castbl))

print(df)
# Out:
# [1] "CASTable"
# attr(,"package")
# [1] "swat"
#    Make                   Model  Type Origin DriveTrain    MSRP Invoice
# 1 Acura                     MDX   SUV   Asia        All $36,945 $33,337
# 2 Acura          RSX Type S 2dr Sedan   Asia      Front $23,820 $21,761
# 3 Acura                 TSX 4dr Sedan   Asia      Front $26,990 $24,647
# 4 Acura                  TL 4dr Sedan   Asia      Front $33,195 $30,299
# 5 Acura              3.5 RL 4dr Sedan   Asia      Front $43,755 $39,014
# 6 Acura 3.5 RL w/Navigation 4dr Sedan   Asia      Front $46,100 $41,100
#   EngineSize Cylinders Horsepower MPG_City MPG_Highway
# 1        3.5         6        265       17          23
# 2        2.0         4        200       24          31
# 3        2.4         4        200       22          29
# 4        3.2         6        270       20          28
# 5        3.5         6        225       18          24
# 6        3.5         6        225       18          24

# %%
summary(df)
# Out:
#      Make              Model               Type              Origin
#  Length:6           Length:6           Length:6           Length:6
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#   DriveTrain            MSRP             Invoice            EngineSize
#  Length:6           Length:6           Length:6           Min.   :2.000
#  Class :character   Class :character   Class :character   1st Qu.:2.600
#  Mode  :character   Mode  :character   Mode  :character   Median :3.350
#                                                           Mean   :3.017
#                                                           3rd Qu.:3.500
#                                                           Max.   :3.500
#    Cylinders       Horsepower       MPG_City      MPG_Highway
#  Min.   :4.000   Min.   :200.0   Min.   :17.00   Min.   :23.00
#  1st Qu.:4.500   1st Qu.:206.2   1st Qu.:18.00   1st Qu.:24.00
#  Median :6.000   Median :225.0   Median :19.00   Median :26.00
#  Mean   :5.333   Mean   :230.8   Mean   :19.83   Mean   :26.50
#  3rd Qu.:6.000   3rd Qu.:255.0   3rd Qu.:21.50   3rd Qu.:28.75
#  Max.   :6.000   Max.   :270.0   Max.   :24.00   Max.   :31.00
