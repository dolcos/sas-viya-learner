# %%
/* Start a CAS session if not already started */
cas;

/* You can also print CAS options if available */
%put NOTE: CASHOST=%sysfunc(getoption(CASHOST));
%put NOTE: CASPORT=%sysfunc(getoption(CASPORT));
%put NOTE: CASTOKEN=%sysfunc(getoption(ACCESS_TOKEN));
# Out:
# 68   ods listing close;ods html5 (id=saspy_internal) options(bitmap_mode='inline') device=svg style=HTMLBlue; ods graphics on /
# 68 ! outputfmt=png;
# NOTE: Writing HTML5(SASPY_INTERNAL) Body file: sashtml4.htm
# 69
# 70   /* Start a CAS session if not already started */
# 71   cas;
# NOTE: The session name identified with the SESSREF= SAS option is connected to Cloud Analytic Services. The default value for
#       SESSREF= is CASAUTO.
# 72
# 73   /* You can also print CAS options if available */
# 74   %put NOTE: CASHOST=%sysfunc(getoption(CASHOST));
# NOTE: CASHOST=sas-cas-server-default-client
# 75   %put NOTE: CASPORT=%sysfunc(getoption(CASPORT));
# NOTE: CASPORT=5570
# 76   %put NOTE: CASTOKEN=%sysfunc(getoption(ACCESS_TOKEN));
# WARNING: Argument 1 to function GETOPTION referenced by the %SYSFUNC or %QSYSFUNC macro function is out of range.
# NOTE: CASTOKEN=
# 77
# 78
# 79   ods html5 (id=saspy_internal) close;ods listing;
# 80
